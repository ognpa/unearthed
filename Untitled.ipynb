# %%
import pandas as pd

df=pd.read_excel("Road Segment Data.xlsx","Report 2")
df['Productivity']=df['Payload']/df.DurationCalculated
truck_spec=pd.read_excel("Truck_Spec.xlsx","Truck Spec")
truck_spec['Truck ID']=truck_spec['Truck ID'].apply(lambda x:'TRH'+str(x))
df=df.merge(truck_spec,left_on='Truck',right_on='Truck ID')
df=df.loc[df.RiseHeight>0,]
df.shape
df=df.drop('LoadStateDirection_D-CR',axis=1)
df.head()
# Out:
#    Unnamed: 0   Truck        Description-CR  Payload  StartVelocity  \
# 2         NaN  TRH404           HRD11-GRD01   195000      12.348000
# 3         NaN  TRH404           HRD11-GRD01   139900      11.700000
# 4         NaN  TRH404  HRD10-NTH_Ramp_Entry   129600      35.460001
# 5         NaN  TRH404  HRD10-NTH_Ramp_Entry   195000      44.784000
# 6         NaN  TRH404           GRD25-GRD26   144800      14.004000
#
#    EndVelocity    EfhLength  TargetDuration  DurationCalculated  SlopeLength  \
# 2       22.032   819.854006              50                34.0   148.646236
# 3       15.048  1213.290345              84                53.0   227.771512
# 4       17.244   344.006622              25                30.0   253.309921
# 5       40.464   361.402519              23                27.0   283.127646
# 6       17.316   347.804409              24                36.0   149.325273
#
#              ...             StartWaypointCoordsY  StartWaypointCoordsZ  \
# 2            ...                     36754.300000           1166.380000
# 3            ...                     36754.300000           1170.561274
# 4            ...                     36663.859375           1212.449951
# 5            ...                     36663.860000           1212.450000
# 6            ...                     36257.250000            879.202123
#
#    EndWaypointCoordsX  EndWaypointCoordsY  EndWaypointCoordsZ_Q-CR  \
# 2          86073.5500        36831.270000              1205.000000
# 3          85987.8100        36835.970000              1200.403173
# 4          85760.5625        36805.621094              1209.920044
# 5          85790.3300        36808.970000              1209.050000
# 6          85976.8400        36378.800000               883.840000
#
#    Productivity  Truck ID  Truck Type Empty Weight (kg)  \
# 2   5735.294118    TRH404        789C            124114
# 3   2639.622642    TRH404        789C            124114
# 4   4320.000000    TRH404        789C            124114
# 5   7222.222222    TRH404        789C            124114
# 6   4022.222222    TRH404        789C            124114
#
#   Max Gross OperatingWeight
# 2                 317514.85
# 3                 317514.85
# 4                 317514.85
# 5                 317514.85
# 6                 317514.85
#
# [5 rows x 22 columns]

# %%
df.groupby('Truck')['Description-CR'].count().sort_values(ascending=True).plot(kind='barh').set_title("Number of times trucks drove in road segment")
# Out:
# Text(0.5,1,'Number of times trucks drove in road segment')

# %%
from matplotlib import rcParams
import seaborn as sns
from matplotlib import pyplot as plt
rcParams['figure.figsize'] = 15, 9
sns.boxplot(x=df.Truck,y=df.Productivity)

# %%
#Outlier in data
df=df[df.Productivity<70000]

# %%
#Crows fly distance travelled
import numpy as np
df=df.rename(columns={'StartWaypointCoordsX':'X1','StartWaypointCoordsY':'Y1','StartWaypointCoordsZ':'Z1',
                   'EndWaypointCoordsX':'X2','EndWaypointCoordsY' :'Y2','EndWaypointCoordsZ_Q-CR':'Z2'                 })


df['euclidean']=np.sqrt((df.X2-df.X1).pow(2)+(df.Y2-df.Y1).pow(2)+(df.Z2-df.Z1).pow(2))
df.head()
# Out:
#    Unnamed: 0   Truck        Description-CR  Payload  StartVelocity  \
# 2         NaN  TRH404           HRD11-GRD01   195000      12.348000
# 3         NaN  TRH404           HRD11-GRD01   139900      11.700000
# 4         NaN  TRH404  HRD10-NTH_Ramp_Entry   129600      35.460001
# 5         NaN  TRH404  HRD10-NTH_Ramp_Entry   195000      44.784000
# 6         NaN  TRH404           GRD25-GRD26   144800      14.004000
#
#    EndVelocity    EfhLength  TargetDuration  DurationCalculated  SlopeLength  \
# 2       22.032   819.854006              50                34.0   148.646236
# 3       15.048  1213.290345              84                53.0   227.771512
# 4       17.244   344.006622              25                30.0   253.309921
# 5       40.464   361.402519              23                27.0   283.127646
# 6       17.316   347.804409              24                36.0   149.325273
#
#       ...               Z1          X2            Y2           Z2  \
# 2     ...      1166.380000  86073.5500  36831.270000  1205.000000
# 3     ...      1170.561274  85987.8100  36835.970000  1200.403173
# 4     ...      1212.449951  85760.5625  36805.621094  1209.920044
# 5     ...      1212.450000  85790.3300  36808.970000  1209.050000
# 6     ...       879.202123  85976.8400  36378.800000   883.840000
#
#    Productivity  Truck ID  Truck Type  Empty Weight (kg)  \
# 2   5735.294118    TRH404        789C             124114
# 3   2639.622642    TRH404        789C             124114
# 4   4320.000000    TRH404        789C             124114
# 5   7222.222222    TRH404        789C             124114
# 6   4022.222222    TRH404        789C             124114
#
#   Max Gross OperatingWeight   euclidean
# 2                 317514.85  140.606571
# 3                 317514.85  215.235220
# 4                 317514.85  243.733149
# 5                 317514.85  270.299080
# 6                 317514.85  122.116078
#
# [5 rows x 23 columns]

# %%
#Total weight the truck is currently carrying
df['total']=df['Empty Weight (kg)']+df['Payload']
df['Over_weight_ind']=0
df.loc[df.total>df['Max Gross OperatingWeight'],'Over_weight_ind']=1
df.loc[:,['Empty Weight (kg)','Payload','Max Gross OperatingWeight','total','Over_weight_ind']].head()
# Out:
#    Empty Weight (kg)  Payload  Max Gross OperatingWeight   total  \
# 2             124114   195000                  317514.85  319114
# 3             124114   139900                  317514.85  264014
# 4             124114   129600                  317514.85  253714
# 5             124114   195000                  317514.85  319114
# 6             124114   144800                  317514.85  268914
#
#    Over_weight_ind
# 2                1
# 3                0
# 4                0
# 5                1
# 6                0

# %%
sns.heatmap(df.corr())

# %%
tc_df=pd.read_csv("Truck Cycle.csv")
tc_df=tc_df.merge(truck_spec,left_on='Truck',right_on='Truck ID')
tc_df['Payload_tonnes']=tc_df['Payload']*(1000)
tc_df['total']=tc_df['Payload_tonnes']+tc_df['Empty Weight (kg)']
tc_df['Overweight']=0
tc_df.loc[tc_df.total>tc_df.loc[:,'Max Gross OperatingWeight'],'Overweight']=1
tc_df.head()
# Out:
#          Date Source Stage  Source bench Destination name   Truck  \
# 0  01/01/2017      Stage G           920         MW_PRIME  TRH402
# 1  01/01/2017      Stage G           912           ROM_01  TRH402
# 2  01/01/2017      Stage G           912          CRUSH01  TRH402
# 3  01/01/2017      Stage G           912           ROM_01  TRH402
# 4  01/01/2017      Stage G           903          CRUSH01  TRH402
#
#    Travelling empty duration  Travelling full duration  Payload  \
# 0                        0.0                      1009    179.7
# 1                     1259.0                      1022    151.9
# 2                      625.0                      1102    184.5
# 3                     1804.0                      1087    168.9
# 4                     2895.0                      1093    173.5
#
#   Full slope length Empty slope length     ...     Inpit Ramp Grade  \
# 0         3,888.21              42.94      ...                9.34%
# 1         4,542.65           4,193.04      ...                9.14%
# 2         5,300.56           4,616.52      ...                9.14%
# 3         5,335.41           6,149.59      ...                9.14%
# 4         5,662.90           5,613.46      ...                9.14%
#
#   Dump Ramp length Dump Ramp Grade Truck ID Truck Type Empty Weight (kg)  \
# 0          336.00            8.33%   TRH402       789C            114114
# 1          135.00            6.67%   TRH402       789C            114114
# 2             -              0.00%   TRH402       789C            114114
# 3          135.00            6.67%   TRH402       789C            114114
# 4             -              0.00%   TRH402       789C            114114
#
#    Max Gross OperatingWeight  Payload_tonnes     total  Overweight
# 0                  317514.85        179700.0  293814.0           0
# 1                  317514.85        151900.0  266014.0           0
# 2                  317514.85        184500.0  298614.0           0
# 3                  317514.85        168900.0  283014.0           0
# 4                  317514.85        173500.0  287614.0           0
#
# [5 rows x 21 columns]

# %%
rcParams['figure.figsize'] = 5, 5

tc_df.Overweight.value_counts().plot(kind='bar').set_title("how many times is the truck overweight")
#Here too payload sometimes is too much for the truck
# Out:
# Text(0.5,1,'how many times is the truck overweight')

# %%
tc_df.dtypes
# Out:
# Date                          object
# Source Stage                  object
# Source bench                   int64
# Destination name              object
# Truck                         object
# Travelling empty duration    float64
# Travelling full duration       int64
# Payload                      float64
# Full slope length             object
# Empty slope length            object
# Inpit Ramp length             object
# Inpit Ramp Grade              object
# Dump Ramp length              object
# Dump Ramp Grade               object
# Truck ID                      object
# Truck Type                    object
# Empty Weight (kg)              int64
# Max Gross OperatingWeight    float64
# Payload_tonnes               float64
# total                        float64
# Overweight                     int64
# dtype: object

# %%
tc_df.head()
# Out:
#          Date Source Stage  Source bench Destination name   Truck  \
# 0  01/01/2017      Stage G           920         MW_PRIME  TRH402
# 1  01/01/2017      Stage G           912           ROM_01  TRH402
# 2  01/01/2017      Stage G           912          CRUSH01  TRH402
# 3  01/01/2017      Stage G           912           ROM_01  TRH402
# 4  01/01/2017      Stage G           903          CRUSH01  TRH402
#
#    Travelling empty duration  Travelling full duration  Payload  \
# 0                        0.0                      1009    179.7
# 1                     1259.0                      1022    151.9
# 2                      625.0                      1102    184.5
# 3                     1804.0                      1087    168.9
# 4                     2895.0                      1093    173.5
#
#   Full slope length Empty slope length     ...     Inpit Ramp Grade  \
# 0         3,888.21              42.94      ...                9.34%
# 1         4,542.65           4,193.04      ...                9.14%
# 2         5,300.56           4,616.52      ...                9.14%
# 3         5,335.41           6,149.59      ...                9.14%
# 4         5,662.90           5,613.46      ...                9.14%
#
#   Dump Ramp length Dump Ramp Grade Truck ID Truck Type Empty Weight (kg)  \
# 0          336.00            8.33%   TRH402       789C            114114
# 1          135.00            6.67%   TRH402       789C            114114
# 2             -              0.00%   TRH402       789C            114114
# 3          135.00            6.67%   TRH402       789C            114114
# 4             -              0.00%   TRH402       789C            114114
#
#    Max Gross OperatingWeight  Payload_tonnes     total  Overweight
# 0                  317514.85        179700.0  293814.0           0
# 1                  317514.85        151900.0  266014.0           0
# 2                  317514.85        184500.0  298614.0           0
# 3                  317514.85        168900.0  283014.0           0
# 4                  317514.85        173500.0  287614.0           0
#
# [5 rows x 21 columns]

# %%
tc_df=tc_df.drop('Payload',axis=1)
tc_df.head()
# Out:
#          Date Source Stage  Source bench Destination name   Truck  \
# 0  01/01/2017      Stage G           920         MW_PRIME  TRH402
# 1  01/01/2017      Stage G           912           ROM_01  TRH402
# 2  01/01/2017      Stage G           912          CRUSH01  TRH402
# 3  01/01/2017      Stage G           912           ROM_01  TRH402
# 4  01/01/2017      Stage G           903          CRUSH01  TRH402
#
#    Travelling empty duration  Travelling full duration Full slope length  \
# 0                        0.0                      1009         3,888.21
# 1                     1259.0                      1022         4,542.65
# 2                      625.0                      1102         5,300.56
# 3                     1804.0                      1087         5,335.41
# 4                     2895.0                      1093         5,662.90
#
#   Empty slope length Inpit Ramp length Inpit Ramp Grade Dump Ramp length  \
# 0             42.94          3,108.02             9.34%          336.00
# 1          4,193.04          3,263.69             9.14%          135.00
# 2          4,616.52          3,263.69             9.14%             -
# 3          6,149.59          3,263.69             9.14%          135.00
# 4          5,613.46          3,362.25             9.14%             -
#
#   Dump Ramp Grade Truck ID Truck Type  Empty Weight (kg)  \
# 0           8.33%   TRH402       789C             114114
# 1           6.67%   TRH402       789C             114114
# 2           0.00%   TRH402       789C             114114
# 3           6.67%   TRH402       789C             114114
# 4           0.00%   TRH402       789C             114114
#
#    Max Gross OperatingWeight  Payload_tonnes     total  Overweight
# 0                  317514.85        179700.0  293814.0           0
# 1                  317514.85        151900.0  266014.0           0
# 2                  317514.85        184500.0  298614.0           0
# 3                  317514.85        168900.0  283014.0           0
# 4                  317514.85        173500.0  287614.0           0

# %%
road_segment_mean_df=df.groupby('Truck',as_index=False).SlopeLength.sum()
road_segment_mean_df.columns=['Truck','Distance_Travelled_From_Pit_Top']


duration_to_pit_df=df.groupby('Truck',as_index=False).DurationCalculated.sum()
duration_to_pit_df.columns=['Truck','Duration_Elapsed_From_Pit_Top']


master_df=tc_df.merge(road_segment_mean_df,on='Truck').merge(duration_to_pit_df,on='Truck')

master_df.head()
# Out:
#          Date Source Stage  Source bench Destination name   Truck  \
# 0  01/01/2017      Stage G           920         MW_PRIME  TRH402
# 1  01/01/2017      Stage G           912           ROM_01  TRH402
# 2  01/01/2017      Stage G           912          CRUSH01  TRH402
# 3  01/01/2017      Stage G           912           ROM_01  TRH402
# 4  01/01/2017      Stage G           903          CRUSH01  TRH402
#
#    Travelling empty duration  Travelling full duration Full slope length  \
# 0                        0.0                      1009         3,888.21
# 1                     1259.0                      1022         4,542.65
# 2                      625.0                      1102         5,300.56
# 3                     1804.0                      1087         5,335.41
# 4                     2895.0                      1093         5,662.90
#
#   Empty slope length Inpit Ramp length              ...                \
# 0             42.94          3,108.02               ...
# 1          4,193.04          3,263.69               ...
# 2          4,616.52          3,263.69               ...
# 3          6,149.59          3,263.69               ...
# 4          5,613.46          3,362.25               ...
#
#   Dump Ramp Grade Truck ID Truck Type Empty Weight (kg)  \
# 0           8.33%   TRH402       789C            114114
# 1           6.67%   TRH402       789C            114114
# 2           0.00%   TRH402       789C            114114
# 3           6.67%   TRH402       789C            114114
# 4           0.00%   TRH402       789C            114114
#
#   Max Gross OperatingWeight  Payload_tonnes     total  Overweight  \
# 0                 317514.85        179700.0  293814.0           0
# 1                 317514.85        151900.0  266014.0           0
# 2                 317514.85        184500.0  298614.0           0
# 3                 317514.85        168900.0  283014.0           0
# 4                 317514.85        173500.0  287614.0           0
#
#    Distance_Travelled_From_Pit_Top  Duration_Elapsed_From_Pit_Top
# 0                    119110.149912                        32487.0
# 1                    119110.149912                        32487.0
# 2                    119110.149912                        32487.0
# 3                    119110.149912                        32487.0
# 4                    119110.149912                        32487.0
#
# [5 rows x 22 columns]

# %%
master_df=master_df.drop('Truck ID',axis=1)
master_df.head()
# Out:
#          Date Source Stage  Source bench Destination name   Truck  \
# 0  01/01/2017      Stage G           920         MW_PRIME  TRH402
# 1  01/01/2017      Stage G           912           ROM_01  TRH402
# 2  01/01/2017      Stage G           912          CRUSH01  TRH402
# 3  01/01/2017      Stage G           912           ROM_01  TRH402
# 4  01/01/2017      Stage G           903          CRUSH01  TRH402
#
#    Travelling empty duration  Travelling full duration Full slope length  \
# 0                        0.0                      1009         3,888.21
# 1                     1259.0                      1022         4,542.65
# 2                      625.0                      1102         5,300.56
# 3                     1804.0                      1087         5,335.41
# 4                     2895.0                      1093         5,662.90
#
#   Empty slope length Inpit Ramp length              ...                \
# 0             42.94          3,108.02               ...
# 1          4,193.04          3,263.69               ...
# 2          4,616.52          3,263.69               ...
# 3          6,149.59          3,263.69               ...
# 4          5,613.46          3,362.25               ...
#
#   Dump Ramp length Dump Ramp Grade Truck Type Empty Weight (kg)  \
# 0          336.00            8.33%       789C            114114
# 1          135.00            6.67%       789C            114114
# 2             -              0.00%       789C            114114
# 3          135.00            6.67%       789C            114114
# 4             -              0.00%       789C            114114
#
#    Max Gross OperatingWeight  Payload_tonnes     total  Overweight  \
# 0                  317514.85        179700.0  293814.0           0
# 1                  317514.85        151900.0  266014.0           0
# 2                  317514.85        184500.0  298614.0           0
# 3                  317514.85        168900.0  283014.0           0
# 4                  317514.85        173500.0  287614.0           0
#
#    Distance_Travelled_From_Pit_Top  Duration_Elapsed_From_Pit_Top
# 0                    119110.149912                        32487.0
# 1                    119110.149912                        32487.0
# 2                    119110.149912                        32487.0
# 3                    119110.149912                        32487.0
# 4                    119110.149912                        32487.0
#
# [5 rows x 21 columns]

# %%
master_df.dtypes
# Out:
# Date                                object
# Source Stage                        object
# Source bench                         int64
# Destination name                    object
# Truck                               object
# Travelling empty duration          float64
# Travelling full duration             int64
# Full slope length                   object
# Empty slope length                  object
# Inpit Ramp length                   object
# Inpit Ramp Grade                    object
# Dump Ramp length                    object
# Dump Ramp Grade                     object
# Truck ID                            object
# Truck Type                          object
# Empty Weight (kg)                    int64
# Max Gross OperatingWeight          float64
# Payload_tonnes                     float64
# total                              float64
# Overweight                           int64
# Distance_Travelled_From_Pit_Top    float64
# Duration_Elapsed_From_Pit_Top      float64
# dtype: object

# %% [markdown]
# # What is the change in productivity as I go deeper? This will have both duration and speed in it

# %%
df.groupby(['Truck','Description-CR']).count()
# Out:
#                        Unnamed: 0  Payload  StartVelocity  EndVelocity  \
# Truck  Description-CR
# TRH401 GRD01-GRD02              0        7              7            7
#        GRD02-GRD03              0        7              7            7
#        GRD03-GRD04              0        7              7            7
#        GRD04-GRD05              0        7              7            7
#        GRD05-GRD06              0        7              7            7
#        GRD06-GRD07              0        7              7            7
#        GRD07-GRD08              0        8              8            8
#        GRD08-GRD09              0        9              9            9
#        GRD09-GRD10              0        9              9            9
#        GRD10-GRD11              0        9              9            9
#        GRD11-GRD12              0       10             10           10
#        GRD12-GRD13              0       10             10           10
#        GRD14-GRD15              0       12             12           12
#        GRD15-GRD16              0       13             13           13
#        GRD16-GRD17              0       13             13           13
#        GRD17-GRD18              0       13             13           13
#        GRD18-GRD19              0       13             13           13
#        GRD19-GRD20              0       13             13           13
#        GRD20-GRD21              0       14             14           14
#        GRD21-GRD22              0       15             15           15
#        GRD22-GRD23              0       16             16           16
#        GRD23-GRD24              0       14             14           14
#        GRD24-GRD25              0       10             10           10
#        GRD25-GRD26              0        7              7            7
#        HRD11-GRD01              0        2              2            2
# TRH402 GRD01-GRD02              0       42             42           42
#        GRD02-GRD03              0       43             43           43
#        GRD03-GRD04              0       41             41           41
#        GRD04-GRD05              0       41             41           41
#        GRD05-GRD06              0       41             41           41
# ...                           ...      ...            ...          ...
# TRH417 GRD20-GRD21              0       17             17           17
#        GRD21-GRD22              0       17             17           17
#        GRD22-GRD23              0       17             17           17
#        GRD23-GRD24              0       17             17           17
#        GRD24-GRD25              0        9              9            9
#        GRD25-GRD26              0       13             13           13
#        HRD11-GRD01              0        3              3            3
# TRH418 GRD01-GRD02              0        2              2            2
#        GRD02-GRD03              0        2              2            2
#        GRD03-GRD04              0        2              2            2
#        GRD04-GRD05              0        2              2            2
#        GRD05-GRD06              0        2              2            2
#        GRD06-GRD07              0        2              2            2
#        GRD07-GRD08              0        2              2            2
#        GRD08-GRD09              0        2              2            2
#        GRD09-GRD10              0        2              2            2
#        GRD10-GRD11              0        2              2            2
#        GRD11-GRD12              0        2              2            2
#        GRD12-GRD13              0        2              2            2
#        GRD14-GRD15              0        2              2            2
#        GRD15-GRD16              0        2              2            2
#        GRD16-GRD17              0        2              2            2
#        GRD17-GRD18              0        2              2            2
#        GRD18-GRD19              0        2              2            2
#        GRD19-GRD20              0        2              2            2
#        GRD20-GRD21              0        2              2            2
#        GRD21-GRD22              0        2              2            2
#        GRD22-GRD23              0        2              2            2
#        GRD23-GRD24              0        2              2            2
#        GRD24-GRD25              0        1              1            1
#
#                        EfhLength  TargetDuration  DurationCalculated  \
# Truck  Description-CR
# TRH401 GRD01-GRD02             7               7                   7
#        GRD02-GRD03             7               7                   7
#        GRD03-GRD04             7               7                   7
#        GRD04-GRD05             7               7                   7
#        GRD05-GRD06             7               7                   7
#        GRD06-GRD07             7               7                   7
#        GRD07-GRD08             8               8                   8
#        GRD08-GRD09             9               9                   9
#        GRD09-GRD10             9               9                   9
#        GRD10-GRD11             9               9                   9
#        GRD11-GRD12            10              10                  10
#        GRD12-GRD13            10              10                  10
#        GRD14-GRD15            12              12                  12
#        GRD15-GRD16            13              13                  13
#        GRD16-GRD17            13              13                  13
#        GRD17-GRD18            13              13                  13
#        GRD18-GRD19            13              13                  13
#        GRD19-GRD20            13              13                  13
#        GRD20-GRD21            14              14                  14
#        GRD21-GRD22            15              15                  15
#        GRD22-GRD23            16              16                  16
#        GRD23-GRD24            14              14                  14
#        GRD24-GRD25            10              10                  10
#        GRD25-GRD26             7               7                   7
#        HRD11-GRD01             2               2                   2
# TRH402 GRD01-GRD02            42              42                  42
#        GRD02-GRD03            43              43                  43
#        GRD03-GRD04            41              41                  41
#        GRD04-GRD05            41              41                  41
#        GRD05-GRD06            41              41                  41
# ...                          ...             ...                 ...
# TRH417 GRD20-GRD21            17              17                  17
#        GRD21-GRD22            17              17                  17
#        GRD22-GRD23            17              17                  17
#        GRD23-GRD24            17              17                  17
#        GRD24-GRD25             9               9                   9
#        GRD25-GRD26            13              13                  13
#        HRD11-GRD01             3               3                   3
# TRH418 GRD01-GRD02             2               2                   2
#        GRD02-GRD03             2               2                   2
#        GRD03-GRD04             2               2                   2
#        GRD04-GRD05             2               2                   2
#        GRD05-GRD06             2               2                   2
#        GRD06-GRD07             2               2                   2
#        GRD07-GRD08             2               2                   2
#        GRD08-GRD09             2               2                   2
#        GRD09-GRD10             2               2                   2
#        GRD10-GRD11             2               2                   2
#        GRD11-GRD12             2               2                   2
#        GRD12-GRD13             2               2                   2
#        GRD14-GRD15             2               2                   2
#        GRD15-GRD16             2               2                   2
#        GRD16-GRD17             2               2                   2
#        GRD17-GRD18             2               2                   2
#        GRD18-GRD19             2               2                   2
#        GRD19-GRD20             2               2                   2
#        GRD20-GRD21             2               2                   2
#        GRD21-GRD22             2               2                   2
#        GRD22-GRD23             2               2                   2
#        GRD23-GRD24             2               2                   2
#        GRD24-GRD25             1               1                   1
#
#                        SlopeLength  RiseHeight  X1       ...         Y2  Z2  \
# Truck  Description-CR                                    ...
# TRH401 GRD01-GRD02               7           7   7       ...          7   7
#        GRD02-GRD03               7           7   7       ...          7   7
#        GRD03-GRD04               7           7   7       ...          7   7
#        GRD04-GRD05               7           7   7       ...          7   7
#        GRD05-GRD06               7           7   7       ...          7   7
#        GRD06-GRD07               7           7   7       ...          7   7
#        GRD07-GRD08               8           8   8       ...          8   8
#        GRD08-GRD09               9           9   9       ...          9   9
#        GRD09-GRD10               9           9   9       ...          9   9
#        GRD10-GRD11               9           9   9       ...          9   9
#        GRD11-GRD12              10          10  10       ...         10  10
#        GRD12-GRD13              10          10  10       ...         10  10
#        GRD14-GRD15              12          12  12       ...         12  12
#        GRD15-GRD16              13          13  13       ...         13  13
#        GRD16-GRD17              13          13  13       ...         13  13
#        GRD17-GRD18              13          13  13       ...         13  13
#        GRD18-GRD19              13          13  13       ...         13  13
#        GRD19-GRD20              13          13  13       ...         13  13
#        GRD20-GRD21              14          14  14       ...         14  14
#        GRD21-GRD22              15          15  15       ...         15  15
#        GRD22-GRD23              16          16  16       ...         16  16
#        GRD23-GRD24              14          14  14       ...         14  14
#        GRD24-GRD25              10          10  10       ...         10  10
#        GRD25-GRD26               7           7   7       ...          7   7
#        HRD11-GRD01               2           2   2       ...          2   2
# TRH402 GRD01-GRD02              42          42  42       ...         42  42
#        GRD02-GRD03              43          43  43       ...         43  43
#        GRD03-GRD04              41          41  41       ...         41  41
#        GRD04-GRD05              41          41  41       ...         41  41
#        GRD05-GRD06              41          41  41       ...         41  41
# ...                            ...         ...  ..       ...         ..  ..
# TRH417 GRD20-GRD21              17          17  17       ...         17  17
#        GRD21-GRD22              17          17  17       ...         17  17
#        GRD22-GRD23              17          17  17       ...         17  17
#        GRD23-GRD24              17          17  17       ...         17  17
#        GRD24-GRD25               9           9   9       ...          9   9
#        GRD25-GRD26              13          13  13       ...         13  13
#        HRD11-GRD01               3           3   3       ...          3   3
# TRH418 GRD01-GRD02               2           2   2       ...          2   2
#        GRD02-GRD03               2           2   2       ...          2   2
#        GRD03-GRD04               2           2   2       ...          2   2
#        GRD04-GRD05               2           2   2       ...          2   2
#        GRD05-GRD06               2           2   2       ...          2   2
#        GRD06-GRD07               2           2   2       ...          2   2
#        GRD07-GRD08               2           2   2       ...          2   2
#        GRD08-GRD09               2           2   2       ...          2   2
#        GRD09-GRD10               2           2   2       ...          2   2
#        GRD10-GRD11               2           2   2       ...          2   2
#        GRD11-GRD12               2           2   2       ...          2   2
#        GRD12-GRD13               2           2   2       ...          2   2
#        GRD14-GRD15               2           2   2       ...          2   2
#        GRD15-GRD16               2           2   2       ...          2   2
#        GRD16-GRD17               2           2   2       ...          2   2
#        GRD17-GRD18               2           2   2       ...          2   2
#        GRD18-GRD19               2           2   2       ...          2   2
#        GRD19-GRD20               2           2   2       ...          2   2
#        GRD20-GRD21               2           2   2       ...          2   2
#        GRD21-GRD22               2           2   2       ...          2   2
#        GRD22-GRD23               2           2   2       ...          2   2
#        GRD23-GRD24               2           2   2       ...          2   2
#        GRD24-GRD25               1           1   1       ...          1   1
#
#                        Productivity  Truck ID  Truck Type  Empty Weight (kg)  \
# Truck  Description-CR
# TRH401 GRD01-GRD02                7         7           7                  7
#        GRD02-GRD03                7         7           7                  7
#        GRD03-GRD04                7         7           7                  7
#        GRD04-GRD05                7         7           7                  7
#        GRD05-GRD06                7         7           7                  7
#        GRD06-GRD07                7         7           7                  7
#        GRD07-GRD08                8         8           8                  8
#        GRD08-GRD09                9         9           9                  9
#        GRD09-GRD10                9         9           9                  9
#        GRD10-GRD11                9         9           9                  9
#        GRD11-GRD12               10        10          10                 10
#        GRD12-GRD13               10        10          10                 10
#        GRD14-GRD15               12        12          12                 12
#        GRD15-GRD16               13        13          13                 13
#        GRD16-GRD17               13        13          13                 13
#        GRD17-GRD18               13        13          13                 13
#        GRD18-GRD19               13        13          13                 13
#        GRD19-GRD20               13        13          13                 13
#        GRD20-GRD21               14        14          14                 14
#        GRD21-GRD22               15        15          15                 15
#        GRD22-GRD23               16        16          16                 16
#        GRD23-GRD24               14        14          14                 14
#        GRD24-GRD25               10        10          10                 10
#        GRD25-GRD26                7         7           7                  7
#        HRD11-GRD01                2         2           2                  2
# TRH402 GRD01-GRD02               42        42          42                 42
#        GRD02-GRD03               43        43          43                 43
#        GRD03-GRD04               41        41          41                 41
#        GRD04-GRD05               41        41          41                 41
#        GRD05-GRD06               41        41          41                 41
# ...                             ...       ...         ...                ...
# TRH417 GRD20-GRD21               17        17          17                 17
#        GRD21-GRD22               17        17          17                 17
#        GRD22-GRD23               17        17          17                 17
#        GRD23-GRD24               17        17          17                 17
#        GRD24-GRD25                9         9           9                  9
#        GRD25-GRD26               13        13          13                 13
#        HRD11-GRD01                3         3           3                  3
# TRH418 GRD01-GRD02                2         2           2                  2
#        GRD02-GRD03                2         2           2                  2
#        GRD03-GRD04                2         2           2                  2
#        GRD04-GRD05                2         2           2                  2
#        GRD05-GRD06                2         2           2                  2
#        GRD06-GRD07                2         2           2                  2
#        GRD07-GRD08                2         2           2                  2
#        GRD08-GRD09                2         2           2                  2
#        GRD09-GRD10                2         2           2                  2
#        GRD10-GRD11                2         2           2                  2
#        GRD11-GRD12                2         2           2                  2
#        GRD12-GRD13                2         2           2                  2
#        GRD14-GRD15                2         2           2                  2
#        GRD15-GRD16                2         2           2                  2
#        GRD16-GRD17                2         2           2                  2
#        GRD17-GRD18                2         2           2                  2
#        GRD18-GRD19                2         2           2                  2
#        GRD19-GRD20                2         2           2                  2
#        GRD20-GRD21                2         2           2                  2
#        GRD21-GRD22                2         2           2                  2
#        GRD22-GRD23                2         2           2                  2
#        GRD23-GRD24                2         2           2                  2
#        GRD24-GRD25                1         1           1                  1
#
#                        Max Gross OperatingWeight  euclidean  total  \
# Truck  Description-CR
# TRH401 GRD01-GRD02                             7          7      7
#        GRD02-GRD03                             7          7      7
#        GRD03-GRD04                             7          7      7
#        GRD04-GRD05                             7          7      7
#        GRD05-GRD06                             7          7      7
#        GRD06-GRD07                             7          7      7
#        GRD07-GRD08                             8          8      8
#        GRD08-GRD09                             9          9      9
#        GRD09-GRD10                             9          9      9
#        GRD10-GRD11                             9          9      9
#        GRD11-GRD12                            10         10     10
#        GRD12-GRD13                            10         10     10
#        GRD14-GRD15                            12         12     12
#        GRD15-GRD16                            13         13     13
#        GRD16-GRD17                            13         13     13
#        GRD17-GRD18                            13         13     13
#        GRD18-GRD19                            13         13     13
#        GRD19-GRD20                            13         13     13
#        GRD20-GRD21                            14         14     14
#        GRD21-GRD22                            15         15     15
#        GRD22-GRD23                            16         16     16
#        GRD23-GRD24                            14         14     14
#        GRD24-GRD25                            10         10     10
#        GRD25-GRD26                             7          7      7
#        HRD11-GRD01                             2          2      2
# TRH402 GRD01-GRD02                            42         42     42
#        GRD02-GRD03                            43         43     43
#        GRD03-GRD04                            41         41     41
#        GRD04-GRD05                            41         41     41
#        GRD05-GRD06                            41         41     41
# ...                                          ...        ...    ...
# TRH417 GRD20-GRD21                            17         17     17
#        GRD21-GRD22                            17         17     17
#        GRD22-GRD23                            17         17     17
#        GRD23-GRD24                            17         17     17
#        GRD24-GRD25                             9          9      9
#        GRD25-GRD26                            13         13     13
#        HRD11-GRD01                             3          3      3
# TRH418 GRD01-GRD02                             2          2      2
#        GRD02-GRD03                             2          2      2
#        GRD03-GRD04                             2          2      2
#        GRD04-GRD05                             2          2      2
#        GRD05-GRD06                             2          2      2
#        GRD06-GRD07                             2          2      2
#        GRD07-GRD08                             2          2      2
#        GRD08-GRD09                             2          2      2
#        GRD09-GRD10                             2          2      2
#        GRD10-GRD11                             2          2      2
#        GRD11-GRD12                             2          2      2
#        GRD12-GRD13                             2          2      2
#        GRD14-GRD15                             2          2      2
#        GRD15-GRD16                             2          2      2
#        GRD16-GRD17                             2          2      2
#        GRD17-GRD18                             2          2      2
#        GRD18-GRD19                             2          2      2
#        GRD19-GRD20                             2          2      2
#        GRD20-GRD21                             2          2      2
#        GRD21-GRD22                             2          2      2
#        GRD22-GRD23                             2          2      2
#        GRD23-GRD24                             2          2      2
#        GRD24-GRD25                             1          1      1
#
#                        Over_weight_ind
# Truck  Description-CR
# TRH401 GRD01-GRD02                   7
#        GRD02-GRD03                   7
#        GRD03-GRD04                   7
#        GRD04-GRD05                   7
#        GRD05-GRD06                   7
#        GRD06-GRD07                   7
#        GRD07-GRD08                   8
#        GRD08-GRD09                   9
#        GRD09-GRD10                   9
#        GRD10-GRD11                   9
#        GRD11-GRD12                  10
#        GRD12-GRD13                  10
#        GRD14-GRD15                  12
#        GRD15-GRD16                  13
#        GRD16-GRD17                  13
#        GRD17-GRD18                  13
#        GRD18-GRD19                  13
#        GRD19-GRD20                  13
#        GRD20-GRD21                  14
#        GRD21-GRD22                  15
#        GRD22-GRD23                  16
#        GRD23-GRD24                  14
#        GRD24-GRD25                  10
#        GRD25-GRD26                   7
#        HRD11-GRD01                   2
# TRH402 GRD01-GRD02                  42
#        GRD02-GRD03                  43
#        GRD03-GRD04                  41
#        GRD04-GRD05                  41
#        GRD05-GRD06                  41
# ...                                ...
# TRH417 GRD20-GRD21                  17
#        GRD21-GRD22                  17
#        GRD22-GRD23                  17
#        GRD23-GRD24                  17
#        GRD24-GRD25                   9
#        GRD25-GRD26                  13
#        HRD11-GRD01                   3
# TRH418 GRD01-GRD02                   2
#        GRD02-GRD03                   2
#        GRD03-GRD04                   2
#        GRD04-GRD05                   2
#        GRD05-GRD06                   2
#        GRD06-GRD07                   2
#        GRD07-GRD08                   2
#        GRD08-GRD09                   2
#        GRD09-GRD10                   2
#        GRD10-GRD11                   2
#        GRD11-GRD12                   2
#        GRD12-GRD13                   2
#        GRD14-GRD15                   2
#        GRD15-GRD16                   2
#        GRD16-GRD17                   2
#        GRD17-GRD18                   2
#        GRD18-GRD19                   2
#        GRD19-GRD20                   2
#        GRD20-GRD21                   2
#        GRD21-GRD22                   2
#        GRD22-GRD23                   2
#        GRD23-GRD24                   2
#        GRD24-GRD25                   1
#
# [401 rows x 23 columns]

# %%
df.loc[(df.Truck=='TRH401')&(df['Description-CR']=='GRD07-GRD08'),:]
# Out:
#       Unnamed: 0   Truck Description-CR  Payload  StartVelocity  EndVelocity  \
# 2650         NaN  TRH401    GRD07-GRD08   177200          1.000       14.832
# 2651         NaN  TRH401    GRD07-GRD08   187400         13.356       12.996
# 2652         NaN  TRH401    GRD07-GRD08   197700          1.000        1.000
# 2653         NaN  TRH401    GRD07-GRD08   179500          1.000        1.000
# 2654         NaN  TRH401    GRD07-GRD08   172700         11.016       11.520
# 2655         NaN  TRH401    GRD07-GRD08   183100         13.104       12.132
# 2656         NaN  TRH401    GRD07-GRD08   188600          1.000        1.000
# 2657         NaN  TRH401    GRD07-GRD08   180700         14.148       12.636
#
#        EfhLength  TargetDuration  DurationCalculated  SlopeLength  \
# 2650  663.393362              46                28.0   170.552364
# 2651  663.393362              46                46.0   170.552364
# 2652  663.393362              46                52.0   170.552364
# 2653  663.393362              46                45.0   170.552364
# 2654  663.393362              46                52.0   170.552364
# 2655  663.393362              46                48.0   170.274254
# 2656  663.393362              46                54.0   170.274254
# 2657  663.393362              46                49.0   170.268928
#
#            ...              Y2       Z2  Productivity  Truck ID  Truck Type  \
# 2650       ...        36084.42  1081.62   6328.571429    TRH401        789C
# 2651       ...        36084.42  1081.62   4073.913043    TRH401        789C
# 2652       ...        36084.42  1081.62   3801.923077    TRH401        789C
# 2653       ...        36084.42  1081.62   3988.888889    TRH401        789C
# 2654       ...        36084.42  1081.62   3321.153846    TRH401        789C
# 2655       ...        36084.42  1081.62   3814.583333    TRH401        789C
# 2656       ...        36084.42  1081.62   3492.592593    TRH401        789C
# 2657       ...        36084.42  1081.62   3687.755102    TRH401        789C
#
#       Empty Weight (kg)  Max Gross OperatingWeight   euclidean   total  \
# 2650             124114                  317514.85  170.552364  301314
# 2651             124114                  317514.85  170.552364  311514
# 2652             124114                  317514.85  170.552364  321814
# 2653             124114                  317514.85  170.552364  303614
# 2654             124114                  317514.85  170.552364  296814
# 2655             124114                  317514.85  167.348972  307214
# 2656             124114                  317514.85  167.348972  312714
# 2657             124114                  317514.85  167.343648  304814
#
#      Over_weight_ind
# 2650               0
# 2651               0
# 2652               1
# 2653               0
# 2654               0
# 2655               0
# 2656               0
# 2657               0
#
# [8 rows x 25 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                   float64
# Truck                         object
# Description-CR                object
# Payload                        int64
# StartVelocity                float64
# EndVelocity                  float64
# EfhLength                    float64
# TargetDuration                 int64
# DurationCalculated           float64
# SlopeLength                  float64
# RiseHeight                   float64
# X1                           float64
# Y1                           float64
# Z1                           float64
# X2                           float64
# Y2                           float64
# Z2                           float64
# Productivity                 float64
# Truck ID                      object
# Truck Type                    object
# Empty Weight (kg)              int64
# Max Gross OperatingWeight    float64
# euclidean                    float64
# total                          int64
# Over_weight_ind                int64
# dtype: object
